# %%
# !git clone https://github.com/machinelearnear/transcribe-podcast-using-whisperx.git
# cd transcribe-podcast-using-whisperx

# %%
# !pip install -r requirements.txt

# %%
# !pip uninstall torchtext torchvision torchdata -y

# %%
# !./run_all.sh
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=AUU9RlDrSo0&ab_channel=ElM%C3%A9todoRebord
# [youtube] AUU9RlDrSo0: Downloading webpage
# [youtube] AUU9RlDrSo0: Downloading android player API JSON
# [youtube] Extracting URL: https://www.youtube.com/watch?v=AUU9RlDrSo0&ab_channel=ElM%C3%A9todoRebord
# [youtube] AUU9RlDrSo0: Downloading webpage
# [youtube] AUU9RlDrSo0: Downloading android player API JSON
# [youtube] Extracting URL: https://www.youtube.com/watch?v=AUU9RlDrSo0&ab_channel=ElM%C3%A9todoRebord
# [youtube] AUU9RlDrSo0: Downloading webpage
# [youtube] AUU9RlDrSo0: Downloading android player API JSON
# [info] AUU9RlDrSo0: Downloading 1 format(s): 140
# [dashsegments] Total fragments: 13
# [download] Destination: output/episode_050_alberto_fernandez/episode_050_alberto_fernandez
# [download] 100% of  124.06MiB in 00:00:03 at 38.35MiB/s0;33m00:00 (frag 13/13)3)
# [FixupM4a] Correcting container of "output/episode_050_alberto_fernandez/episode_050_alberto_fernandez"
# ...
